# %%
a=[100,2,78,81,50]

# %%
a.argmin()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-2c67faa16ca6> in <module>()
# ----> 1 a.argmin()
#
# AttributeError: 'list' object has no attribute 'argmin'
