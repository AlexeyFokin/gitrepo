# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t", header=0)

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
len(chipo)
# Out:
# 4622

# %%
# Solution 2

chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
c = chipo.groupby(['item_name'])
c.sum().sort_values(by='quantity', ascending=False).head(1)
# Out:
# 'Chips and Fresh Tomato Salsa'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
c = chipo.groupby(['item_name'])
c.sum().sort_values(by='quantity', ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
c=chipo.groupby('choice_description')
c.sum().sort_values(by='quantity', ascending=False)
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
# ...                                                      ...       ...
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...       577         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...       585         1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, ...       235         1
# [Roasted Chili Corn Salsa, [Guacamole, Sour Cre...       987         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1299         1
#
# [1043 rows x 2 columns]

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo['item_price'].str[0]
# Out:
# 0       $
# 1       $
# 2       $
# 3       $
# 4       $
#        ..
# 4617    $
# 4618    $
# 4619    $
# 4620    $
# 4621    $
# Name: item_price, Length: 4622, dtype: object

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price_f'] = pd.to_numeric(chipo['item_price'].str[1:], downcast='float')
chipo['item_price_f'].dtypes
# Out:
# dtype('float32')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
item_price_f = lambda x: float(x[1:])
chipo['item_price_f'] = chipo.item_price.apply(item_price_f)
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo.item_price_f.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
(chipo.item_price_f * chipo.quantity).sum()
# Out:
# 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
chipo.order_id.value_counts().count()
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1

chipo['revenue'] = chipo.item_price_f * chipo.quantity

g = chipo.groupby('order_id')
g.sum().revenue.mean()
# Out:
# 21.39423118865867

# %%
# Solution 2

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
chipo.item_name.value_counts().count()
# Out:
# 50
