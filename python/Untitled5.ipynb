# %%
import numpy as np
import cv2 as cv
im = cv.imread('science.jpg')
imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(imgray, 127, 255, 0)
im2, contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-97d5594cf9d6> in <module>()
#       4 import cv2 as cv
#       5 im = cv.imread('science.jpg')
# ----> 6 imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
#       7 ret, thresh = cv.threshold(imgray, 127, 255, 0)
#       8 im2, contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
