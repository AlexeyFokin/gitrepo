# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
from plotly.figure_factory import create_table

# %%
gapminder = px.data.gapminder()

# %%
gapminder
# Out:
#           country continent  year  ...   gdpPercap  iso_alpha  iso_num
# 0     Afghanistan      Asia  1952  ...  779.445314        AFG        4
# 1     Afghanistan      Asia  1957  ...  820.853030        AFG        4
# 2     Afghanistan      Asia  1962  ...  853.100710        AFG        4
# 3     Afghanistan      Asia  1967  ...  836.197138        AFG        4
# 4     Afghanistan      Asia  1972  ...  739.981106        AFG        4
# ...           ...       ...   ...  ...         ...        ...      ...
# 1699     Zimbabwe    Africa  1987  ...  706.157306        ZWE      716
# 1700     Zimbabwe    Africa  1992  ...  693.420786        ZWE      716
# 1701     Zimbabwe    Africa  1997  ...  792.449960        ZWE      716
# 1702     Zimbabwe    Africa  2002  ...  672.038623        ZWE      716
# 1703     Zimbabwe    Africa  2007  ...  469.709298        ZWE      716
#
# [1704 rows x 8 columns]

# %%
gapminder.head()
# Out:
#        country continent  year  ...   gdpPercap  iso_alpha  iso_num
# 0  Afghanistan      Asia  1952  ...  779.445314        AFG        4
# 1  Afghanistan      Asia  1957  ...  820.853030        AFG        4
# 2  Afghanistan      Asia  1962  ...  853.100710        AFG        4
# 3  Afghanistan      Asia  1967  ...  836.197138        AFG        4
# 4  Afghanistan      Asia  1972  ...  739.981106        AFG        4
#
# [5 rows x 8 columns]

# %%
table = create_table(gapminder.head(12))

# %%
type(table)
# Out:
# plotly.graph_objs._figure.Figure

# %%
py.iplot(table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="193efd03-d52c-465d-b88a-7a3b127f0f57" class="plotly-graph-div" style="height:440px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("193efd03-d52c-465d-b88a-7a3b127f0f57")) {
#                     Plotly.newPlot(
#                         '193efd03-d52c-465d-b88a-7a3b127f0f57',
# ...

# %%
data = px.data.gapminder().query("year == 2002")
data = data.sort_values(by='lifeExp', ascending = False)
data.head()
# Out:
#                country continent  year  ...    gdpPercap  iso_alpha  iso_num
# 802              Japan      Asia  2002  ...  28604.59190        JPN      392
# 670   Hong Kong, China      Asia  2002  ...  30209.01516        HKG      344
# 1486       Switzerland    Europe  2002  ...  34480.95771        CHE      756
# 694            Iceland    Europe  2002  ...  31163.20196        ISL      352
# 70           Australia   Oceania  2002  ...  30687.75473        AUS       36
#
# [5 rows x 8 columns]

# %%
fig = px.bar(data, x='country', y='lifeExp', height=400, width=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="906b293d-7d7b-4a9e-a43b-83a5bb6cd3d3" class="plotly-graph-div" style="height:400px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("906b293d-7d7b-4a9e-a43b-83a5bb6cd3d3")) {
#                     Plotly.newPlot(
#                         '906b293d-7d7b-4a9e-a43b-83a5bb6cd3d3',
# ...

# %%
import pandas as pd

import seaborn as sns
import plotly.express as px

# %%
import numpy as np
arr = np.random.rand(500,4)
df = pd.DataFrame(arr, columns=['A', 'B', 'C', 'D'])

# %%
from plotly.offline import iplot

# %%
import chart_studio.plotly as py

# %%
px.scatter(df, x='A', y='B', width=400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="080d58e6-393f-431a-8451-434260a6232a" class="plotly-graph-div" style="height:525px; width:400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("080d58e6-393f-431a-8451-434260a6232a")) {
#                     Plotly.newPlot(
#                         '080d58e6-393f-431a-8451-434260a6232a',
# ...

# %%
df_stock = px.data.stocks()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-efc9854cbecb> in <module>()
# ----> 1 df_stock = px.data.stocks()
#
# AttributeError: module 'plotly.express.data' has no attribute 'stocks'
