# %%
import numpy as np

aa = np.array([1,2,3])
a = np.array([[0,1,2,3,4,5], [10,11,12,13,14,15]])
i = np.array([0,1],[1,3])
a[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-37baaf900930> in <module>()
#       3 aa = np.array([1,2,3])
#       4 a = np.array([[0,1,2,3,4,5], [10,11,12,13,14,15]])
# ----> 5 i = np.array([0,1],[1,3])
#       6 a[i]
#       7
#
# TypeError: data type not understood
